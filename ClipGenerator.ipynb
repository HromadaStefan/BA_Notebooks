# %%
import os
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel
from diffusers import DiffusionPipeline

# Initialisiere CLIP und Diffusion-Modell
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
diffusion_model = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, use_safetensors=True, variant="fp16").to("cuda")

source_dir = './images/car/real/'
target_dir = './images/car/fake_ImgToImg/'

# Erstelle den Zielordner, falls er nicht existiert
if not os.path.exists(target_dir):
    os.makedirs(target_dir)

def resize_and_crop(image, target_width=256, target_height=256):
    width, height = image.size

    # Berechne den neuen Größen und den Ausschnitt, um das Bild mittig zu beschneiden
    if width > height:
        scale = target_height / height
        resized_width = int(width * scale)
        resized_height = target_height
        image = image.resize((resized_width, resized_height), Image.LANCZOS)
        left = (resized_width - target_width) / 2
        top = 0
        right = (resized_width + target_width) / 2
        bottom = target_height
    else:
        scale = target_width / width
        resized_width = target_width
        resized_height = int(height * scale)
        image = image.resize((resized_width, resized_height), Image.LANCZOS)
        left = 0
        top = (resized_height - target_height) / 2
        right = target_width
        bottom = (resized_height + target_height) / 2

    # Schneide das Bild mittig zu
    image = image.crop((left, top, right, bottom))
    return image

# Definiere Prompts für die Bildbeschreibung
prompts = [
    "new car",
    "old car",
]

# Durchlaufe alle Dateien im Quellordner
for filename in os.listdir(source_dir):
    file_path = os.path.join(source_dir, filename)
    
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        print(filename.split(".")[0])
        if int(filename.split(".")[0]) < 804:
            continue
        init_image = Image.open(file_path)
        init_image = resize_and_crop(init_image)

        # Verwende CLIP, um einen beschreibenden Prompt für das Bild zu generieren
        inputs = clip_processor(text=prompts, images=init_image, return_tensors="pt")
        outputs = clip_model(**inputs)
        logits_per_image = outputs.logits_per_image
        probs = logits_per_image.softmax(dim=1)
        best_prompt_index = probs.argmax()
        prompt_with_label = prompts[best_prompt_index]

        # Verwende den beschreibenden Prompt für die Bildgenerierung mit dem Diffusion-Modell
        generated_image = diffusion_model(prompt_with_label, image=init_image, strength=0.8, guidance_scale=8).images[0]

        # Speichere das generierte Bild
        save_path = os.path.join(target_dir, 'generated_' + prompt_with_label.replace(" ", "_") + filename)
        generated_image.save(save_path)

        print(f"Bild generiert und gespeichert als: {save_path}")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# 00001
# 00002
# 00003
# 00004
# 00005
# 00006
# 00007
# 00008
# 00009
# 00010
# 00011
# 00012
# 00013
# 00014
# 00015
# 00016
# 00017
# 00018
# 00019
# 00020
# 00021
# 00022
# 00023
# 00024
# 00025
# 00026
# 00027
# 00028
# 00029
# 00030
# 00031
# 00032
# 00033
# 00034
# 00035
# 00036
# 00037
# 00038
# 00039
# 00040
# 00041
# 00042
# 00043
# 00044
# 00045
# 00046
# 00047
# 00048
# 00049
# 00050
# 00051
# 00052
# 00053
# 00054
# 00055
# 00056
# 00057
# 00058
# 00059
# 00060
# 00061
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02766.jpg
# 02767
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02767.jpg
# 02768
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02768.jpg
# 02769
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02769.jpg
# 02770
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02770.jpg
# 02771
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02771.jpg
# 02772
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02772.jpg
# 02773
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02773.jpg
# 02774
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02774.jpg
# 02775
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02775.jpg
# 02776
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02776.jpg
# 02777
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02777.jpg
# 02778
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02778.jpg
# 02779
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02779.jpg
# 02780
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02780.jpg
# 02781
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_old_car02781.jpg
# 02782
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02782.jpg
# 02783
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02783.jpg
# 02784
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02784.jpg
# 02785
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02785.jpg
# 02786
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02786.jpg
# 02787
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02787.jpg
# 02788
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02788.jpg
# 02789
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02789.jpg
# 02790
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02790.jpg
# 02791
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02791.jpg
# 02792
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02792.jpg
# 02793
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02793.jpg
# 02794
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02794.jpg
# 02795
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02795.jpg
# 02796
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02796.jpg
# 02797
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02797.jpg
# 02798
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02798.jpg
# 02799
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02799.jpg
# 02800
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02800.jpg
# 02801
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02801.jpg
# 02802
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02802.jpg
# 02803
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02803.jpg
# 02804
#   0%|          | 0/50 [00:00<?, ?it/s]
# Bild generiert und gespeichert als: ./images/car/fake_ImgToImg/generated_new_car02804.jpg
# 02805
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 72
#      69 prompt_with_label = prompts[best_prompt_index]
#      71 # Verwende den beschreibenden Prompt für die Bildgenerierung mit dem Diffusion-Modell
# ---> 72 generated_image = diffusion_model(prompt_with_label, image=init_image, strength=0.8, guidance_scale=8).images[0]
#      74 # Speichere das generierte Bild
#      75 save_path = os.path.join(target_dir, 'generated_' + prompt_with_label.replace(" ", "_") + filename)
#
# File C:\Python39\lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File C:\Python39\lib\site-packages\diffusers\pipelines\stable_diffusion_xl\pipeline_stable_diffusion_xl.py:1256, in StableDiffusionXLPipeline.__call__(self, prompt, prompt_2, height, width, num_inference_steps, timesteps, denoising_end, guidance_scale, negative_prompt, negative_prompt_2, num_images_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, pooled_prompt_embeds, negative_pooled_prompt_embeds, ip_adapter_image, ip_adapter_image_embeds, output_type, return_dict, cross_attention_kwargs, guidance_rescale, original_size, crops_coords_top_left, target_size, negative_original_size, negative_crops_coords_top_left, negative_target_size, clip_skip, callback_on_step_end, callback_on_step_end_tensor_inputs, **kwargs)
#    1253 if not output_type == "latent":
#    1254     # apply watermark if available
#    1255     if self.watermark is not None:
# -> 1256         image = self.watermark.apply_watermark(image)
#    1258     image = self.image_processor.postprocess(image, output_type=output_type)
#    1260 # Offload all models
#
# File C:\Python39\lib\site-packages\diffusers\pipelines\stable_diffusion_xl\watermark.py:29, in StableDiffusionXLWatermarker.apply_watermark(self, images)
#      26 if images.shape[-1] < 256:
#      27     return images
# ---> 29 images = (255 * (images / 2 + 0.5)).cpu().permute(0, 2, 3, 1).float().numpy()
#      31 images = [self.encoder.encode(image, "dwtDct") for image in images]
#      33 images = torch.from_numpy(np.array(images)).permute(0, 3, 1, 2)
#
# KeyboardInterrupt:
